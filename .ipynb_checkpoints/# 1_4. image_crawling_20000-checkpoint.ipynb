# %%
# 1. pandas 선언
import pandas as pd
# 2. 엑셀 파일 불러오기
df = pd.read_excel(r'C:\Users\dkddk\Desktop\images_ver02.xlsx')
print(df)
# Out:
#        이름   직업             생일    나이 Unnamed: 4
# 0     감우성   배우  1970.10.01(목)  50.0        자세히
# 1     강호동  개그맨  1970.06.11(목)  51.0        자세히
# 2     고창석   배우  1970.10.13(화)  50.0        자세히
# 3     김경식   가수  1970.11.23(월)  50.0        자세히
# 4     김구라  방송인  1970.10.03(토)  50.0        자세히
# ...   ...  ...            ...   ...        ...
# 2232  전소미   가수  2001.03.09(금)  20.0        자세히
# 2233  한현민   모델  2001.05.19(토)  20.0        자세히
# 2234  이수민   배우  2001.07.01(일)  20.0        자세히
# 2235  추예진   배우  2001.10.11(목)  19.0        자세히
# 2236  차준환   선수  2001.10.21(일)  19.0        자세히
#
# [2237 rows x 5 columns]

# %%
# 3.엑셀 값을 list로 변환
df_list = df.values.tolist()
df_list
# Out:
# [['감우성', '배우', '1970.10.01(목)', 50.0, '자세히'],
#  ['강호동', '개그맨', '1970.06.11(목)', 51.0, '자세히'],
#  ['고창석', '배우', '1970.10.13(화)', 50.0, '자세히'],
#  ['김경식', '가수', '1970.11.23(월)', 50.0, '자세히'],
#  ['김구라', '방송인', '1970.10.03(토)', 50.0, '자세히'],
#  ['김나운', '배우', '1970.05.11(월)', 51.0, '자세히'],
#  ['김상호', '배우', '1970.07.24(금)', 51.0, '자세히'],
#  ['김수로', '배우', '1970.05.07(목)', 51.0, '자세히'],
#  ['김학도', '방송인', '1970.02.12(목)', 51.0, '자세히'],
#  ['김현철', '개그맨', '1970.09.27(일)', 50.0, '자세히'],
#  ['김혜수', '배우', '1970.09.05(토)', 50.0, '자세히'],
#  ['김희정', '배우', '1970.12.04(금)', 50.0, '자세히'],
#  ['남성진', '배우', '1970.12.31(목)', 50.0, '자세히'],
#  ['류승룡', '배우', '1970.11.29(일)', 50.0, '자세히'],
#  ['박명수', '방송인', '1970.08.27(목)', 50.0, '자세히'],
#  ['박상민', '배우', '1970.10.19(월)', 50.0, '자세히'],
#  ['박수홍', '개그맨', '1970.10.27(화)', 50.0, '자세히'],
#  ['백재현', '개그맨', '1970.02.24(화)', 51.0, '자세히'],
#  ['손성훈', '가수', '1970.10.21(수)', 50.0, '자세히'],
#  ['손지창', '가수', '1970.02.20(금)', 51.0, '자세히'],
# ...

# %%
# 4. 불러온 엑셀의 column 값 가져오기
df_col = list([col for col in df])
df_col
# Out:
# ['이름', '직업', '생일', '나이', 'Unnamed: 4']

# %%
df_list
# Out:
# [['감우성', '배우', '1970.10.01(목)', 50.0, '자세히'],
#  ['강호동', '개그맨', '1970.06.11(목)', 51.0, '자세히'],
#  ['고창석', '배우', '1970.10.13(화)', 50.0, '자세히'],
#  ['김경식', '가수', '1970.11.23(월)', 50.0, '자세히'],
#  ['김구라', '방송인', '1970.10.03(토)', 50.0, '자세히'],
#  ['김나운', '배우', '1970.05.11(월)', 51.0, '자세히'],
#  ['김상호', '배우', '1970.07.24(금)', 51.0, '자세히'],
#  ['김수로', '배우', '1970.05.07(목)', 51.0, '자세히'],
#  ['김학도', '방송인', '1970.02.12(목)', 51.0, '자세히'],
#  ['김현철', '개그맨', '1970.09.27(일)', 50.0, '자세히'],
#  ['김혜수', '배우', '1970.09.05(토)', 50.0, '자세히'],
#  ['김희정', '배우', '1970.12.04(금)', 50.0, '자세히'],
#  ['남성진', '배우', '1970.12.31(목)', 50.0, '자세히'],
#  ['류승룡', '배우', '1970.11.29(일)', 50.0, '자세히'],
#  ['박명수', '방송인', '1970.08.27(목)', 50.0, '자세히'],
#  ['박상민', '배우', '1970.10.19(월)', 50.0, '자세히'],
#  ['박수홍', '개그맨', '1970.10.27(화)', 50.0, '자세히'],
#  ['백재현', '개그맨', '1970.02.24(화)', 51.0, '자세히'],
#  ['손성훈', '가수', '1970.10.21(수)', 50.0, '자세히'],
#  ['손지창', '가수', '1970.02.20(금)', 51.0, '자세히'],
# ...

# %%
# df로 변환
df = pd.DataFrame(df_list, columns=df_col)
df
# Out:
#        이름   직업             생일    나이 Unnamed: 4
# 0     감우성   배우  1970.10.01(목)  50.0        자세히
# 1     강호동  개그맨  1970.06.11(목)  51.0        자세히
# 2     고창석   배우  1970.10.13(화)  50.0        자세히
# 3     김경식   가수  1970.11.23(월)  50.0        자세히
# 4     김구라  방송인  1970.10.03(토)  50.0        자세히
# ...   ...  ...            ...   ...        ...
# 2232  전소미   가수  2001.03.09(금)  20.0        자세히
# 2233  한현민   모델  2001.05.19(토)  20.0        자세히
# 2234  이수민   배우  2001.07.01(일)  20.0        자세히
# 2235  추예진   배우  2001.10.11(목)  19.0        자세히
# 2236  차준환   선수  2001.10.21(일)  19.0        자세히
#
# [2237 rows x 5 columns]

# %%
df['이름']
# Out:
# 0       감우성
# 1       강호동
# 2       고창석
# 3       김경식
# 4       김구라
#        ...
# 2232    전소미
# 2233    한현민
# 2234    이수민
# 2235    추예진
# 2236    차준환
# Name: 이름, Length: 2237, dtype: object

# %%
df['이름'].tolist()
# Out:
# ['감우성',
#  '강호동',
#  '고창석',
#  '김경식',
#  '김구라',
#  '김나운',
#  '김상호',
#  '김수로',
#  '김학도',
#  '김현철',
#  '김혜수',
#  '김희정',
#  '남성진',
#  '류승룡',
#  '박명수',
#  '박상민',
#  '박수홍',
#  '백재현',
#  '손성훈',
#  '손지창',
#  '심현섭',
#  '염경환',
#  '오현경',
#  '유해진',
#  '이범수',
#  '이병헌',
#  '이상은',
#  '이성재',
#  '이세창',
#  '이연수',
#  '이철민',
#  '임원희',
#  '임호',
#  '장미화',
#  '장현성',
#  '전미선',
#  '정석용',
#  '정재영',
#  '정재형',
#  '조민희',
#  '조혜련',
#  '지상렬',
#  '차승원',
#  '최성국',
#  '최진영',
#  '황정민',
#  '김희원',
#  '강성진',
#  '노정렬',
#  '정웅인',
#  '이서진',
#  '이영애',
#  '황석정',
#  '현진영',
#  '홍석천',
#  '박소현',
#  '신동엽',
#  '김진수',
#  '마동석',
#  '고현정',
#  '박용우',
#  '정준하',
#  '정성한',
#  '김태우',
#  '유희열',
#  '이하늘',
#  '김남주',
#  '서지오',
#  '박노식',
#  '김경호',
#  '지진희',
#  '남희석',
#  '박혁권',
#  '김정난',
#  '김연우',
#  '김승수',
#  '윤기원',
#  '이지은',
#  '이미연',
#  '송일국',
#  '강수정',
#  '김바다',
#  '오연수',
#  '안재욱',
#  '권오중',
#  '이혜영',
#  '최승경',
#  '허동환',
#  '장서희',
#  '임채원',
#  '박진영',
#  '리마리오',
#  '정선희',
#  '윤도현',
#  '김지선',
#  '윤정수',
#  '이윤석',
#  '이상아',
#  '서경석',
#  '김정학',
# ...

# %%
name = df['이름'].tolist()
print(name)
# Out:
# ['감우성', '강호동', '고창석', '김경식', '김구라', '김나운', '김상호', '김수로', '김학도', '김현철', '김혜수', '김희정', '남성진', '류승룡', '박명수', '박상민', '박수홍', '백재현', '손성훈', '손지창', '심현섭', '염경환', '오현경', '유해진', '이범수', '이병헌', '이상은', '이성재', '이세창', '이연수', '이철민', '임원희', '임호', '장미화', '장현성', '전미선', '정석용', '정재영', '정재형', '조민희', '조혜련', '지상렬', '차승원', '최성국', '최진영', '황정민', '김희원', '강성진', '노정렬', '정웅인', '이서진', '이영애', '황석정', '현진영', '홍석천', '박소현', '신동엽', '김진수', '마동석', '고현정', '박용우', '정준하', '정성한', '김태우', '유희열', '이하늘', '김남주', '서지오', '박노식', '김경호', '지진희', '남희석', '박혁권', '김정난', '김연우', '김승수', '윤기원', '이지은', '이미연', '송일국', '강수정', '김바다', '오연수', '안재욱', '권오중', '이혜영', '최승경', '허동환', '장서희', '임채원', '박진영', '리마리오', '정선희', '윤도현', '김지선', '윤정수', '이윤석', '이상아', '서경석', '김정학', '서태지', '장웅', '임혁필', '장동건', '배기성', '정경호', '이준혁', '김민종', '진경', '이장훈', '이아현', '김석훈', '김성재', '고명환', '이현경', '전효실', '전영미', '김상경', '김한석', '유태웅', '안재환', '김원희', '장진영', '김여진', '백현진', '강병규', '이세준', '염정아', '유재석', '김지현', '노현희', '김민희', '배용준', '이현도', '김가연', '위양호', '김태균', '심은하', '윤택', '김주혁', '박주미', '류시원', '백원길',
# ...

# %%
def name_chunked(name, n):
    return [name[i:i+n] for i in range(0, len(name), n)]

print("분할 전 : ", name)

name_list = name_chunked (name, 7)
print("분할 후 : ", name_list)
# Out:
# 분할 전 :  ['감우성', '강호동', '고창석', '김경식', '김구라', '김나운', '김상호', '김수로', '김학도', '김현철', '김혜수', '김희정', '남성진', '류승룡', '박명수', '박상민', '박수홍', '백재현', '손성훈', '손지창', '심현섭', '염경환', '오현경', '유해진', '이범수', '이병헌', '이상은', '이성재', '이세창', '이연수', '이철민', '임원희', '임호', '장미화', '장현성', '전미선', '정석용', '정재영', '정재형', '조민희', '조혜련', '지상렬', '차승원', '최성국', '최진영', '황정민', '김희원', '강성진', '노정렬', '정웅인', '이서진', '이영애', '황석정', '현진영', '홍석천', '박소현', '신동엽', '김진수', '마동석', '고현정', '박용우', '정준하', '정성한', '김태우', '유희열', '이하늘', '김남주', '서지오', '박노식', '김경호', '지진희', '남희석', '박혁권', '김정난', '김연우', '김승수', '윤기원', '이지은', '이미연', '송일국', '강수정', '김바다', '오연수', '안재욱', '권오중', '이혜영', '최승경', '허동환', '장서희', '임채원', '박진영', '리마리오', '정선희', '윤도현', '김지선', '윤정수', '이윤석', '이상아', '서경석', '김정학', '서태지', '장웅', '임혁필', '장동건', '배기성', '정경호', '이준혁', '김민종', '진경', '이장훈', '이아현', '김석훈', '김성재', '고명환', '이현경', '전효실', '전영미', '김상경', '김한석', '유태웅', '안재환', '김원희', '장진영', '김여진', '백현진', '강병규', '이세준', '염정아', '유재석', '김지현', '노현희', '김민희', '배용준', '이현도', '김가연', '위양호', '김태균', '심은하', '윤택', '김주혁', '박주미', '류시원'
# ...

# %%
str_list = []

for person in name_list:
    str_list.append(','.join(person))

# %%
for str_concat in str_list:
    print(str_concat)
# Out:
# 감우성,강호동,고창석,김경식,김구라,김나운,김상호
# 김수로,김학도,김현철,김혜수,김희정,남성진,류승룡
# 박명수,박상민,박수홍,백재현,손성훈,손지창,심현섭
# 염경환,오현경,유해진,이범수,이병헌,이상은,이성재
# 이세창,이연수,이철민,임원희,임호,장미화,장현성
# 전미선,정석용,정재영,정재형,조민희,조혜련,지상렬
# 차승원,최성국,최진영,황정민,김희원,강성진,노정렬
# 정웅인,이서진,이영애,황석정,현진영,홍석천,박소현
# 신동엽,김진수,마동석,고현정,박용우,정준하,정성한
# 김태우,유희열,이하늘,김남주,서지오,박노식,김경호
# 지진희,남희석,박혁권,김정난,김연우,김승수,윤기원
# 이지은,이미연,송일국,강수정,김바다,오연수,안재욱
# 권오중,이혜영,최승경,허동환,장서희,임채원,박진영
# 리마리오,정선희,윤도현,김지선,윤정수,이윤석,이상아
# 서경석,김정학,서태지,장웅,임혁필,장동건,배기성
# 정경호,이준혁,김민종,진경,이장훈,이아현,김석훈
# 김성재,고명환,이현경,전효실,전영미,김상경,김한석
# 유태웅,안재환,김원희,장진영,김여진,백현진,강병규
# 이세준,염정아,유재석,김지현,노현희,김민희,배용준
# 이현도,김가연,위양호,김태균,심은하,윤택,김주혁
# 박주미,류시원,백원길,고소영,김명민,이태식,김성주
# 션,엄정필,박호산,김지수,서춘화,류진,배성우
# 이한철,미나,김정태,이정재,박수림,황수정,이휘재
# 송은이,우기홍,박성웅,바비킴,남상아,신영일,최은경
# 예지원,장은비,이승준,전도연,김성민,신은경,김원준
# 임상아,조장혁,김혜은,박윤선,이장우,박진우,김조한
# 김재만,유경아,웅산,박정환,김형중,정우성,황혜영
# 문수진,하수빈,김지훈,이훈,추상미,이상화,성대현
# 송송이,윤지숙,김성수,소희정,김생민,유재명,박희진
# 송윤아,김민,얀,이상민,홍지민,임태경,손지연
# 이혁재,정재용,송요셉,서영은,이윤성,나원주,한재석
# 김진,김영필,오협,구본승,윤상현,유채영,BMK
# 김선아,박강수,김상태,유혜정,김시원,최승민,김서형
# ...

# %%
### 2만장 다운로드 이미지
#from google_images_download import google_images_download   #importing the library

#response = google_images_download.googleimagesdownload()   #class instantiation

#arguments = {"keywords": str_list[0],"limit":10,"print_urls":True, "format":"jpg"} #creating list of argumentscd
#paths = response.download(arguments)   #passing the arguments to the function
#print(paths)   #printing absolute paths of the downloaded imagescd

# %%
# 라이브러리 불러오기
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import urllib
import time

# 구글이미지 검색해서 해당 사진 가져오기
driver = webdriver.Chrome()
driver.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")
for j in name[0:2100]:
    elem = driver.find_element_by_name("q")
    elem.clear()
    elem.send_keys(j)
    elem.send_keys(Keys.RETURN)

    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")

    count = 1

    for i in images[1:11]: # 1번과 2번 사진이 공통된 사진이므로, 2번 부터 실행
        try:
            i.click()
            time.sleep(1)
            img_url = driver.find_element_by_css_selector(".n3VNCb").get_attribute("src")
            urllib.request.urlretrieve(img_url, j + str(count) + ".jpg")
            count = count + 1
        except:
            pass
    
driver.close() # 창 닫기

# %%
# name
